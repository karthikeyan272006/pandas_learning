# %%
import pandas as pd
df = pd.read_csv('data/patients.csv')

# %%
df.head(5)
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
df=df.set_index('patient_id')

# %%
df
# Out:
#                            name  age arrival_date departure_date  \
# patient_id
# PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ...                         ...  ...          ...            ...
# PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#                        service  satisfaction
# patient_id
# PAT-09484753           surgery            61
# PAT-f0644084           surgery            83
# ...
