# %% [markdown]
# Access the column or feature

# %%
import pandas as pd
df =pd.read_csv('data/patients.csv')
df

# %% [markdown]
# using a square bracket

# %%
# access single column in bracket
df['patient_id']

# %%
#getting value as dataframe
df[['patient_id']]

# %%
# access multiple columns in double brackets
patient = df[['patient_id','name','age']]

# %% [markdown]
# using dot notation

# %%
df.patient_id

# %% [markdown]
# using get method

# %%
df.get('patient_id')
# df.get(['patient_id','name','age'])
