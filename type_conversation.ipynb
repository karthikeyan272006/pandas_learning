# %% [markdown]
# type conversation
# is essential for optimized the data

# %%
import pandas as pd

# %%
df = pd.read_csv('data/patients.csv')
df
# Out:
#        patient_id               name  age arrival_date departure_date  \
# 0    PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1    PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2    PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3    PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4    PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
# ..            ...                ...  ...          ...            ...
# 995  PAT-a01bf534         Amber Vang   26   2025-12-02     2025-12-04
# 996  PAT-87fa07bd       Martha Smith   89   2025-11-18     2025-11-30
# 997  PAT-8f07e894     Jennifer James   72   2025-12-12     2025-12-21
# 998  PAT-4ae301e1     Kara Hernandez   47   2025-02-08     2025-02-20
# 999  PAT-e2ef9c5f    Lorraine Turner   64   2025-05-04     2025-05-08
#
#               service  satisfaction
# 0             surgery            61
# 1             surgery            83
# ...

# %%
df.dtypes
# Out:
# patient_id          str
# name                str
# age               int64
# arrival_date        str
# departure_date      str
# service             str
# satisfaction      int64
# dtype: object

# %%
df.memory_usage(deep = True).sum()/1028
# Out:
# np.float64(306.6225680933852)

# %%
# type conversion in series
df['age']=df['age'].astype('int8')

# %%
df.dtypes
# Out:
# patient_id          str
# name                str
# age                int8
# arrival_date        str
# departure_date      str
# service             str
# satisfaction      int64
# dtype: object

# %%
# type conversation in dataframe
df =df.astype({'patient_id':'str',
           'name':'str',
           'satisfaction':'int8'})

# %%
df.dtypes
# Out:
# patient_id         str
# name               str
# age               int8
# arrival_date       str
# departure_date     str
# service            str
# satisfaction      int8
# dtype: object

# %%
df.memory_usage(deep = True).sum()/1028
# Out:
# np.float64(293.00389105058366)

# %%
df=df.astype({'service':'category'})

# %%
df.dtypes
# Out:
# patient_id             str
# name                   str
# age                   int8
# arrival_date           str
# departure_date         str
# service           category
# satisfaction          int8
# dtype: object

# %%
df.memory_usage(deep = True).sum()
# Out:
# np.int64(244699)
