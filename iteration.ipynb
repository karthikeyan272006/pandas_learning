# %% [markdown]
# Iterating rows

# %%
import pandas as pd
df = pd.read_csv('data/patients.csv')
df.head()
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
list(df.iterrows())
# Out:
# [(0,
#   patient_id             PAT-09484753
#   name              Richard Rodriguez
#   age                              24
#   arrival_date             2025-03-16
#   departure_date           2025-03-22
#   service                     surgery
#   satisfaction                     61
#   Name: 0, dtype: object),
#  (1,
#   patient_id          PAT-f0644084
#   name              Shannon Walker
#   age                            6
#   arrival_date          2025-12-13
#   departure_date        2025-12-14
#   service                  surgery
#   satisfaction                  83
#   Name: 1, dtype: object),
#  (2,
#   patient_id            PAT-ac6162e4
#   name                  Julia Torres
#   age                             24
#   arrival_date            2025-06-29
#   departure_date          2025-07-05
#   service           general_medicine
#   satisfaction                    83
#   Name: 2, dtype: object),
#  (3,
#   patient_id           PAT-3dda2bb5
# ...

# %%
for rows in df.iterrows():
    if rows[1]['service'] == "surgery":
      print(rows)
# Out:
# (0, patient_id             PAT-09484753
# name              Richard Rodriguez
# age                              24
# arrival_date             2025-03-16
# departure_date           2025-03-22
# service                     surgery
# satisfaction                     61
# Name: 0, dtype: object)
# (1, patient_id          PAT-f0644084
# name              Shannon Walker
# age                            6
# arrival_date          2025-12-13
# departure_date        2025-12-14
# service                  surgery
# satisfaction                  83
# Name: 1, dtype: object)
# (14, patient_id        PAT-cc50ad71
# name               Helen Jones
# age                         31
# arrival_date        2025-06-11
# departure_date      2025-06-23
# service                surgery
# satisfaction                92
# Name: 14, dtype: object)
# (26, patient_id         PAT-13c9b20f
# name              Robert Potter
# age                          10
# arrival_date         2025-07-14
# ...

# %%
df1 =list(df.itertuples())
df1
# Out:
# [Pandas(Index=0, patient_id='PAT-09484753', name='Richard Rodriguez', age=24, arrival_date='2025-03-16', departure_date='2025-03-22', service='surgery', satisfaction=61),
#  Pandas(Index=1, patient_id='PAT-f0644084', name='Shannon Walker', age=6, arrival_date='2025-12-13', departure_date='2025-12-14', service='surgery', satisfaction=83),
#  Pandas(Index=2, patient_id='PAT-ac6162e4', name='Julia Torres', age=24, arrival_date='2025-06-29', departure_date='2025-07-05', service='general_medicine', satisfaction=83),
#  Pandas(Index=3, patient_id='PAT-3dda2bb5', name='Crystal Johnson', age=32, arrival_date='2025-10-12', departure_date='2025-10-23', service='emergency', satisfaction=81),
#  Pandas(Index=4, patient_id='PAT-08591375', name='Garrett Lin', age=25, arrival_date='2025-02-18', departure_date='2025-02-25', service='ICU', satisfaction=76),
# ...
