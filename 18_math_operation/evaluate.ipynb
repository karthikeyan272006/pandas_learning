# %%
import pandas as pd

# %%
df= pd.DataFrame({'Qty':[10,20,30],
                 'Price':[100,200,300]})
df
# Out:
#    Qty  Price
# 0   10    100
# 1   20    200
# 2   30    300

# %%
# df['Total'] = df["Qty"] * df['Price']
df.eval('Total = Qty * Price ')
# Out:
#    Qty  Price  Total
# 0   10    100   1000
# 1   20    200   4000
# 2   30    300   9000
