# %% [markdown]
# Series

# %%
import pandas as pd

# %%
#creating a series 
a=pd.Series([1,5,9,5,87])
a
# Out:
# 0     1
# 1     5
# 2     9
# 3     5
# 4    87
# dtype: int64

# %%
fruits =pd.Series(('apple','banana','orange'))
fruits
fruits[1] # accessing the data using index
fruits.index=['a','b','c']
fruits['a']
# Out:
# 'apple'

# %%
fruits.name ='Fruits Series'

# %%
fruits
# Out:
# 0     apple
# 1    banana
# 2    orange
# Name: Fruits Series, dtype: str
